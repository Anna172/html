# %% [markdown]
# <a href="https://colab.research.google.com/github/Anna172/html/blob/master/%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.stats import nct
r = nct.rvs(4, 4, size=10, random_state = 122)
print('1)')
r
# Out:
# 1)
# array([10.27574068,  6.78302234,  3.61935832,  2.7905699 ,  4.18953624,
#         4.47108545,  3.60763175,  3.68994188,  6.31100226,  3.663127  ])

# %%
print('2)')
print('mean: ' + str(round(r.mean(), 2)))
print('var: ' + str(round(r.var(), 2)))
# Out:
# 2)
# mean: 9.0
# var: 10.7

# %%
print('3)')
print("Доверительный интервал: [" + str(r.mean() - 3 * np.sqrt(r.var())) + "; " + str(r.mean() + 3 * np.sqrt(r.var())) + "]")
print("Доверительный интервал: [-0.81; 18.82]")
# Out:
# 3)
# Доверительный интервал: [-0.8119391159202554; 18.81257101867199]
# Доверительный интервал: [-0.81; 18.82]

# %%
print('4)')
print('Среднее попало в доверительный интервал')
# Out:
# 4)
# Среднее попало в доверительный интервал

# %%
print('5)')
from scipy.stats import uniform
r_new = nct.rvs(4, 4, size=9, random_state = 122).tolist()
r2 = uniform.rvs(loc=3, scale=2, size=1, random_state = 122)
print()
r_new.append(r2[0])
print('Новая выборка: ' + str(r_new))
print('Наблюдения с альтернативным распреелением: ' + str(r2))
# Out:
# 5)
#
# Новая выборка: [7.363807220596805, 5.305978968749942, 4.068797035563833, 2.252494902614862, 13.366969108173901, 2.59142735090818, 2.620259592804004, 5.366387835468077, 4.002088842378198, 3.313983675783333]
# Наблюдения с альтернативным распреелением: [3.31398368]

# %% [markdown]
# Новая выборка: [7.363807220596805, 5.305978968749942, 4.068797035563833, 2.252494902614862, 13.366969108173901, 2.59142735090818, 2.620259592804004, 5.366387835468077, 4.002088842378198, **3.313983675783333**]

# %%
import numpy as np
print('6_2)')
print('mean: ' + str(round(np.mean(r_new), 2)))
print('var: ' + str(round(np.var(r_new), 2)))
# Out:
# 6_2)
# mean: 5.07
# var: 9.81

# %%
print('6_3)')
print("Доверительный интервал: [" + str(np.mean(r_new) - 3 * np.sqrt(np.var(r_new))) + "; " + str(np.mean(r_new) + 3 * np.sqrt(np.var(r_new))) + "]")
print("Доверительный интервал: [-4.32; 14.47]")
# Out:
# 6_3)
# Доверительный интервал: [-4.325002011915047; 14.469636021258275]
# Доверительный интервал: [-4.32; 14.47]

# %%
print('6_4)')
print('Среднее попало в доверительный интервал')
# Out:
# 6_4)
# Среднее попало в доверительный интервал

# %%
print('7_1)')
print('5_1)')

r_new = nct.rvs(4, 4, size=9, random_state = 120).tolist()
r2 = uniform.rvs(loc=3, scale=2, size=1, random_state = 120)
print()
r_new.append(r2[0])
print('Новая выборка: ' + str(r_new))
print('Наблюдения с альтернативным распреелением: ' + str(r2) + '\n')

print('6_2_1)')
print('mean: ' + str(round(np.mean(r_new), 2)))
print('var: ' + str(round(np.var(r_new), 2)) + '\n')

print('6_3_1)')
print("Доверительный интервал: [" + str(np.mean(r_new) - 3 * np.sqrt(np.var(r_new))) + "; " + str(np.mean(r_new) + 3 * np.sqrt(np.var(r_new))) + "]")
print("Доверительный интервал: [-0.66; 11.74]" + '\n')

print('6_4_1)')
print('Среднее попало в доверительный интервал')
# Out:
# 7_1)
# 5_1)
#
# Новая выборка: [4.728263080874096, 9.80313974047367, 2.522053126466311, 6.872898058579144, 4.756461187009816, 4.275259637651439, 5.980909161110699, 3.9578387419468264, 8.116599941671328, 4.3559110964171515]
# Наблюдения с альтернативным распреелением: [4.3559111]
#
# 6_2_1)
# mean: 5.54
# var: 4.27
#
# 6_3_1)
# Доверительный интервал: [-0.6600728823038997; 11.733939636743997]
# Доверительный интервал: [-0.66; 11.74]
#
# 6_4_1)
# Среднее попало в доверительный интервал

# %%
print('7_2)')
print('5_2)')

r_new = nct.rvs(4, 4, size=9, random_state = 121).tolist()
r2 = uniform.rvs(loc=3, scale=2, size=1, random_state = 121)
print()
r_new.append(r2[0])
print('Новая выборка: ' + str(r_new))
print('Наблюдения с альтернативным распреелением: ' + str(r2) + '\n')

print('6_2_2)')
print('mean: ' + str(round(np.mean(r_new), 2)))
print('var: ' + str(round(np.var(r_new), 2)) + '\n')

print('6_3_2)')
print("Доверительный интервал: [" + str(np.mean(r_new) - 3 * np.sqrt(np.var(r_new))) + "; " + str(np.mean(r_new) + 3 * np.sqrt(np.var(r_new))) + "]")
print("Доверительный интервал: [1.21; 6.13]" + '\n')

print('6_4_2)')
print('Среднее попало в доверительный интервал')
# Out:
# 7_2)
# 5_2)
#
# Новая выборка: [3.3102938477468133, 4.558165492922484, 2.610527005794748, 4.1435991031253945, 3.1339503597204708, 3.7763389916800456, 5.504622076162404, 3.5361865573393327, 2.930894211382509, 3.222661656010489]
# Наблюдения с альтернативным распреелением: [3.22266166]
#
# 6_2_2)
# mean: 3.67
# var: 0.67
#
# 6_3_2)
# Доверительный интервал: [1.2182688827743493; 6.127178977602588]
# Доверительный интервал: [1.21; 6.13]
#
# 6_4_2)
# Среднее попало в доверительный интервал

# %%
print('7_3)')
print('5_3)')

r_new = nct.rvs(4, 4, size=9, random_state = 123).tolist()
r2 = uniform.rvs(loc=3, scale=2, size=1, random_state = 123)
print()
r_new.append(r2[0])
print('Новая выборка: ' + str(r_new))
print('Наблюдения с альтернативным распреелением: ' + str(r2) + '\n')

print('6_2_3)')
print('mean: ' + str(round(np.mean(r_new), 2)))
print('var: ' + str(round(np.var(r_new), 2)) + '\n')

print('6_3_3)')
print("Доверительный интервал: [" + str(np.mean(r_new) - 3 * np.sqrt(np.var(r_new))) + "; " + str(np.mean(r_new) + 3 * np.sqrt(np.var(r_new))) + "]")
print("Доверительный интервал: [-2.20; 13.18]" + '\n')

print('6_4_3)')
print('Среднее попало в доверительный интервал')
# Out:
# 7_3)
# 5_3)
#
# Новая выборка: [4.668394551953295, 5.792995025643507, 6.092845865939962, 2.6031196601567883, 6.92762736756031, 5.221427894528083, 1.3324080861032432, 6.460559831772303, 11.376852393273154, 4.392938371195723]
# Наблюдения с альтернативным распреелением: [4.39293837]
#
# 6_2_3)
# mean: 5.49
# var: 6.57
#
# 6_3_3)
# Доверительный интервал: [-2.2020592946420816; 13.175893104267354]
# Доверительный интервал: [-2.20; 13.18]
#
# 6_4_3)
# Среднее попало в доверительный интервал

# %%
print('7_4)')
print('5_4)')

r_new = nct.rvs(4, 4, size=9, random_state = 124).tolist()
r2 = uniform.rvs(loc=3, scale=2, size=1, random_state = 124)
print()
r_new.append(r2[0])
print('Новая выборка: ' + str(r_new))
print('Наблюдения с альтернативным распреелением: ' + str(r2) + '\n')

print('6_2_4)')
print('mean: ' + str(round(np.mean(r_new), 2)))
print('var: ' + str(round(np.var(r_new), 2)) + '\n')

print('6_3_4)')
print("Доверительный интервал: [" + str(np.mean(r_new) - 3 * np.sqrt(np.var(r_new))) + "; " + str(np.mean(r_new) + 3 * np.sqrt(np.var(r_new))) + "]")
print("Доверительный интервал: [-0.21; 9.51]" + '\n')

print('6_4_4)')
print('Среднее попало в доверительный интервал')
# Out:
# 7_4)
# 5_4)
#
# Новая выборка: [6.395217609242344, 4.329041686406796, 4.430334848752455, 5.322080209383708, 1.7165079793589086, 3.095737184514594, 7.462732824306891, 4.558108830954082, 5.922039227370824, 3.2121298119094654]
# Наблюдения с альтернативным распреелением: [3.21212981]
#
# 6_2_4)
# mean: 4.64
# var: 2.63
#
# 6_3_4)
# Доверительный интервал: [-0.21847665780173653; 9.50726270024175]
# Доверительный интервал: [-0.21; 9.51]
#
# 6_4_4)
# Среднее попало в доверительный интервал

# %%
print('7_5)')
print('5_5)')

r_new = nct.rvs(4, 4, size=9, random_state = 125).tolist()
r2 = uniform.rvs(loc=3, scale=2, size=1, random_state = 125)
print()
r_new.append(r2[0])
print('Новая выборка: ' + str(r_new))
print('Наблюдения с альтернативным распреелением: ' + str(r2) + '\n')

print('6_2_5)')
print('mean: ' + str(round(np.mean(r_new), 2)))
print('var: ' + str(round(np.var(r_new), 2)) + '\n')

print('6_3_5)')
print("Доверительный интервал: [" + str(np.mean(r_new) - 3 * np.sqrt(np.var(r_new))) + "; " + str(np.mean(r_new) + 3 * np.sqrt(np.var(r_new))) + "]")
print("Доверительный интервал: [-3.00; 10.96]" + '\n')

print('6_4_5)')
print('Среднее попало в доверительный интервал')
# Out:
# 7_5)
# 5_5)
#
# Новая выборка: [1.640495868773553, 2.068917782982397, 2.053648133113206, 3.467457862305185, 6.0052336462029885, 4.253729860479568, 2.7786269263751096, 9.91724374739834, 3.5587449896496177, 4.0134520229991395]
# Наблюдения с альтернативным распреелением: [4.01345202]
#
# 6_2_5)
# mean: 3.98
# var: 5.41
#
# 6_3_5)
# Доверительный интервал: [-3.005168229449805; 10.956678397505627]
# Доверительный интервал: [-3.00; 10.96]
#
# 6_4_5)
# Среднее попало в доверительный интервал

# %%
print('7_6)')
print('5_6)')

r_new = nct.rvs(4, 4, size=9, random_state = 126).tolist()
r2 = uniform.rvs(loc=3, scale=2, size=1, random_state = 126)
print()
r_new.append(r2[0])
print('Новая выборка: ' + str(r_new))
print('Наблюдения с альтернативным распреелением: ' + str(r2) + '\n')

print('6_2_)')
print('mean: ' + str(round(np.mean(r_new), 2)))
print('var: ' + str(round(np.var(r_new), 2)) + '\n')

print('6_3_6)')
print("Доверительный интервал: [" + str(np.mean(r_new) - 3 * np.sqrt(np.var(r_new))) + "; " + str(np.mean(r_new) + 3 * np.sqrt(np.var(r_new))) + "]")
print("Доверительный интервал: [-0.05; 8.25]" + '\n')

print('6_4_6)')
print('Среднее попало в доверительный интервал')
# Out:
# 7_6)
# 5_6)
#
# Новая выборка: [3.7600437745586084, 6.473039951127727, 5.699670711872916, 3.492545790143646, 3.2494987081697655, 1.267159582469627, 4.742387109526153, 4.820194657394668, 4.234001896190333, 3.21034425443535]
# Наблюдения с альтернативным распреелением: [3.21034425]
#
# 6_2_)
# mean: 4.09
# var: 1.92
#
# 6_3_6)
# Доверительный интервал: [-0.058101548757570676; 8.247878835935328]
# Доверительный интервал: [-0.05; 8.25]
#
# 6_4_6)
# Среднее попало в доверительный интервал

# %%
print('8_1)')
print('5_1)')

r_new = nct.rvs(4, 4, size=9 * 2, random_state = 122).tolist()
r2 = uniform.rvs(loc=3, scale=2, size=1 * 2, random_state = 122).tolist()
print()
r_new = r_new + r2
print('Длина новой выборки: ' + str(len(r_new)))
print('Новая выборка: ' + str(r_new))
print('Наблюдения с альтернативным распреелением: ' + str(r2) + '\n')

print('6_2_1)')
print('mean: ' + str(round(np.mean(r_new), 2)))
print('var: ' + str(round(np.var(r_new), 2)) + '\n')

print('6_3_1)')
print("Доверительный интервал: [" + str(np.mean(r_new) - 3 * np.sqrt(np.var(r_new))) + "; " + str(np.mean(r_new) + 3 * np.sqrt(np.var(r_new))) + "]")
print("Доверительный интервал: [-3.37; 13.13]" + '\n')

print('6_4_1)')
print('Среднее попало в доверительный интервал')
# Out:
# 8_1)
# 5_1)
#
# Длина новой выборки: 20
# Новая выборка: [5.355968756840465, 2.3278547413142605, 6.341159832978384, 3.2228845478844765, 4.793182514397395, 3.547696347473944, 3.106647183999809, 4.373901981872485, 4.083323016899634, 3.3277905956970297, 5.063355362852741, 1.1403484676781828, 4.297603417154135, 4.224177845601712, 2.8084994887847907, 11.486282121503688, 7.848982880867174, 12.434993133071119, 3.313983675783333, 4.404420084984892]
# Наблюдения с альтернативным распреелением: [3.313983675783333, 4.404420084984892]
#
# 6_2_1)
# mean: 4.88
# var: 7.56
#
# 6_3_1)
# Доверительный интервал: [-3.371885354037908; 13.122190953801873]
# Доверительный интервал: [-3.37; 13.13]
#
# 6_4_1)
# Среднее попало в доверительный интервал

# %%
print('8_2)')
print('5_2)')

r_new = nct.rvs(4, 4, size=9 * 4, random_state = 122).tolist()
r2 = uniform.rvs(loc=3, scale=2, size=1 * 4, random_state = 122).tolist()
print()
r_new = r_new + r2
print('Длина новой выборки: ' + str(len(r_new)))
print('Новая выборка: ' + str(r_new))
print('Наблюдения с альтернативным распреелением: ' + str(r2) + '\n')

print('6_2_2)')
print('mean: ' + str(round(np.mean(r_new), 2)))
print('var: ' + str(round(np.var(r_new), 2)) + '\n')

print('6_3_2)')
print("Доверительный интервал: [" + str(np.mean(r_new) - 3 * np.sqrt(np.var(r_new))) + "; " + str(np.mean(r_new) + 3 * np.sqrt(np.var(r_new))) + "]")
print("Доверительный интервал: [-4.34; 14.60]" + '\n')

print('6_4_2)')
print('Среднее попало в доверительный интервал')
# Out:
# 8_2)
# 5_2)
#
# Длина новой выборки: 40
# Новая выборка: [3.11599215323907, 3.945787727564753, 4.22212154556026, 3.0594024451859205, 6.155095291910969, 6.938489194608704, 3.9820715351482576, 12.950392043609108, 14.133876705734147, 3.8904238176472927, 2.0761620600222166, 0.9790416413650754, 6.263028335082309, 6.742314635945922, 1.1243219326984448, 3.609621280494278, 6.916731398923536, 4.476018250772242, 2.834946066007376, 4.0597915217405935, 5.288768844551567, 4.520642751424594, 2.8545189820981096, 3.6718115252787227, 10.853734725220992, 5.333927180126709, 11.58087779462986, 2.633741661823356, 13.413464141944832, 3.743990345789642, 4.103106053212086, 4.401713297870117, 3.8988661629755534, 2.634282105679945, 6.131760766052134, 3.505419869473608, 3.313983675783333, 4.404420084984892, 3.522956532782497, 3.903425816022934]
# Наблюдения с альтернативным распреелением: [3.313983675783333, 4.404420084984892, 3.522956532782497, 3.903425816022934]
#
# 6_2_2)
# mean: 5.13
# var: 9.96
#
# ...

# %%
print('8_3)')
print('5_3)')

r_new = nct.rvs(4, 4, size=9 * 8, random_state = 122).tolist()
r2 = uniform.rvs(loc=3, scale=2, size=1 * 8, random_state = 122).tolist()
print()
r_new = r_new + r2
print('Длина новой выборки: ' + str(len(r_new)))
print('Новая выборка: ' + str(r_new))
print('Наблюдения с альтернативным распреелением: ' + str(r2) + '\n')

print('6_2_3)')
print('mean: ' + str(round(np.mean(r_new), 2)))
print('var: ' + str(round(np.var(r_new), 2)) + '\n')

print('6_3_3)')
print("Доверительный интервал: [" + str(np.mean(r_new) - 3 * np.sqrt(np.var(r_new))) + "; " + str(np.mean(r_new) + 3 * np.sqrt(np.var(r_new))) + "]")
print("Доверительный интервал: [-4.18; 14.03]" + '\n')

print('6_4_3)')
print('Среднее попало в доверительный интервал')
# Out:
# 8_3)
# 5_3)
#
# Длина новой выборки: 80
# ...

# %%
print('8_4)')
print('5_4)')

r_new = nct.rvs(4, 4, size=9 * 16, random_state = 122).tolist()
r2 = uniform.rvs(loc=3, scale=2, size=1 * 16, random_state = 122).tolist()
print()
r_new = r_new + r2
print('Длина новой выборки: ' + str(len(r_new)))
print('Новая выборка: ' + str(r_new))
print('Наблюдения с альтернативным распреелением: ' + str(r2) + '\n')

print('6_2_4)')
print('mean: ' + str(round(np.mean(r_new), 2)))
print('var: ' + str(round(np.var(r_new), 2)) + '\n')

print('6_3_4)')
print("Доверительный интервал: [" + str(np.mean(r_new) - 3 * np.sqrt(np.var(r_new))) + "; " + str(np.mean(r_new) + 3 * np.sqrt(np.var(r_new))) + "]")
print("Доверительный интервал: [-2.88; 12.06]" + '\n')

print('6_4_4)')
print('Среднее попало в доверительный интервал')
# Out:
# 8_4)
# 5_4)
#
# Длина новой выборки: 160
# ...

# %% [markdown]
# 9) В результате эксперимента, каждое среднее значение случайно сгенерированной выборки, имеющей распределение стьюдента, попало в расчитанный по правилу трех сигм доверительный интервал. Следовательно, правило трех сигм хорошо работает для распределения Стьюдента. Более того, среднее значение выборки примерно совпадало с серединой доверительного интервала, поэтому для среднего значения данного распределения можно строить доверительные интервалы меньшей длины без существенных потерь в точности.

# %% [markdown]
# 10) Несмотря на то, что выборка была испорчена равномерным распределением на отрезке [3, 5], все полученные в результате эксперимента средние значения выборки попали в доверительный интервал построенный по правилам трех сигм. Это можно объяснить тем, что альтернативное распределение занимало лишь 10% от выбоки. Более того, альтернативное распределение всегда принимало значения в области доверительного интервала, и как следствие, не оказывало существенного влияния на значение сренего, дисперсии и доверительного интервала. Так же стоит отметить, что равномерное распределение имеет и среднее значение и дисперсию, что делает возможным применение к нему правила трех сигм для построения доверительного интервала для среднего значения.
